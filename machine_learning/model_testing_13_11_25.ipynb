# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import matplotlib.pyplot as plt

# %% [markdown]
# # Import ml model

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
from tensorflow.keras.models import load_model as lm

# %%
model = lm('/content/drive/MyDrive/plant_disease_model_2025_11_09.keras')

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 128, 128, 32)   │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 126, 126, 32)   │         9,248 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 63, 63, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 63, 63, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (None, 61, 61, 64)     │        36,928 │
# ...

# %% [markdown]
# # Image visualization

# %%
import cv2
from os import listdir
from os.path import isfile , join
import random

# %%
Path = "/content/drive/MyDrive/plant_test_images"
images_path = join(Path , 'test')
images = listdir(images_path)
print(images)
n = len(images)
n
# Out:
# ['PotatoHealthy1.JPG', 'AppleCedarRust3.JPG', 'AppleCedarRust2.JPG', 'PotatoEarlyBlight5.JPG', 'TomatoEarlyBlight1.JPG', 'TomatoYellowCurlVirus2.JPG', 'TomatoYellowCurlVirus5.JPG', 'CornCommonRust2.JPG', 'PotatoEarlyBlight4.JPG', 'TomatoEarlyBlight4.JPG', 'AppleCedarRust4.JPG', 'TomatoHealthy3.JPG', 'TomatoYellowCurlVirus1.JPG', 'CornCommonRust3.JPG', 'CornCommonRust1.JPG', 'PotatoEarlyBlight3.JPG', 'AppleScab1.JPG', 'PotatoHealthy2.JPG', 'TomatoEarlyBlight2.JPG', 'TomatoEarlyBlight6.JPG', 'TomatoHealthy2.JPG', 'TomatoHealthy4.JPG', 'TomatoYellowCurlVirus3.JPG', 'AppleCedarRust1.JPG', 'PotatoEarlyBlight1.JPG', 'TomatoHealthy1.JPG', 'TomatoEarlyBlight5.JPG', 'AppleScab2.JPG', 'AppleScab3.JPG', 'PotatoEarlyBlight2.JPG', 'TomatoEarlyBlight3.JPG', 'TomatoYellowCurlVirus4.JPG', 'TomatoYellowCurlVirus6.JPG']
# 33

# %%
def get_prediction(image_path):
  image = tf.keras.preprocessing.image.load_img(image_path , target_size = (128 , 128))
  input_arr = tf.keras.preprocessing.image.img_to_array(image)
  input_arr = np.array([input_arr])
  prediction = model.predict(input_arr)
  result = np.argmax(prediction)
  return result , prediction[0][result]

# %% [markdown]
# # Testing model

# %%
classes_names = ['Apple___Apple_scab',
 'Apple___Black_rot',
 'Apple___Cedar_apple_rust',
 'Apple___healthy',
 'Blueberry___healthy',
 'Cherry_(including_sour)___Powdery_mildew',
 'Cherry_(including_sour)___healthy',
 'Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot',
 'Corn_(maize)___Common_rust_',
 'Corn_(maize)___Northern_Leaf_Blight',
 'Corn_(maize)___healthy',
 'Grape___Black_rot',
 'Grape___Esca_(Black_Measles)',
 'Grape___Leaf_blight_(Isariopsis_Leaf_Spot)',
 'Grape___healthy',
 'Orange___Haunglongbing_(Citrus_greening)',
 'Peach___Bacterial_spot',
 'Peach___healthy',
 'Pepper,_bell___Bacterial_spot',
 'Pepper,_bell___healthy',
 'Potato___Early_blight',
 'Potato___Late_blight',
 'Potato___healthy',
 'Raspberry___healthy',
 'Soybean___healthy',
 'Squash___Powdery_mildew',
 'Strawberry___Leaf_scorch',
 'Strawberry___healthy',
 'Tomato___Bacterial_spot',
 'Tomato___Early_blight',
 'Tomato___Late_blight',
 'Tomato___Leaf_Mold',
 'Tomato___Septoria_leaf_spot',
 'Tomato___Spider_mites Two-spotted_spider_mite',
 'Tomato___Target_Spot',
 'Tomato___Tomato_Yellow_Leaf_Curl_Virus',
 'Tomato___Tomato_mosaic_virus',
 'Tomato___healthy']

# %%
def predict_image(image , path_join = False):

  image_path = join(images_path , image) if path_join else image
  result , per = get_prediction(image_path)

  return classes_names[result].replace('_','.') + str( f"{per*100:.2f}%" )

# %%
for image in images:
  print(f'input image : {image} ~~ predicted class : {predict_image(image , True)}')
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# input image : PotatoHealthy1.JPG ~~ predicted class : Potato...healthy97.28%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# input image : AppleCedarRust3.JPG ~~ predicted class : Apple...Cedar.apple.rust97.58%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# input image : AppleCedarRust2.JPG ~~ predicted class : Apple...Cedar.apple.rust99.81%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# input image : PotatoEarlyBlight5.JPG ~~ predicted class : Potato...Early.blight98.42%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# input image : TomatoEarlyBlight1.JPG ~~ predicted class : Tomato...Late.blight85.70%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# input image : TomatoYellowCurlVirus2.JPG ~~ predicted class : Tomato...Tomato.Yellow.Leaf.Curl.Virus100.00%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# input image : TomatoYellowCurlVirus5.JPG ~~ predicted class : Tomato...Tomato.Yellow.Leaf.Curl.Virus100.00%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# ...

# %%
import gradio as gr

# %%
def classify_plant_disease(image_file_path):
  """Predicts the plant disease from an uploaded image file path."""
  # image_file_path will be the temporary file path provided by Gradio
  result_idx, confidence = get_prediction(image_file_path)
  predicted_class = classes_names[result_idx].replace('_', ' ') # Replace underscores for better readability
  return f"Predicted Class: {predicted_class} (Confidence: {confidence*100:.2f}%)"

# Create the Gradio interface
iface = gr.Interface(
    fn=classify_plant_disease,
    inputs=gr.Image(type="filepath", label="Upload Plant Image"), # Accepts file path from Gradio
    outputs="text",
    title="Plant Disease Classifier",
    description="Upload an image of a plant leaf to get a prediction of its disease."
)

# Launch the interface
iface.launch(debug=False, share=True)
